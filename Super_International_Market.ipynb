# %% [markdown]
# <a href="https://colab.research.google.com/github/alvionas/Data-Analyst/blob/main/Super_International_Market.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/MyDrive")
# Out:
# Drive already mounted at /content/MyDrive; to attempt to forcibly remount, call drive.mount("/content/MyDrive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt

# %%
data = pd.read_csv("/content/MyDrive/MyDrive/Super_International_Market.csv", encoding='latin1')
data
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891  31-07-2012  31-07-2012        Same Day
# 1       26341    IN-2013-77878    2/5/2013    5/2/2013    Second Class
# 2       25330    IN-2013-71249  17-10-2013  17-10-2013     First Class
# 3       13524  ES-2013-1579342  28-01-2013  28-01-2013     First Class
# 4       47221     SG-2013-4320   11/5/2013   5/11/2013        Same Day
# ...       ...              ...         ...         ...             ...
# 51285   29002    IN-2014-62366  19-06-2014  19-06-2014        Same Day
# 51286   35398   US-2014-102288  20-06-2014  20-06-2014  Standard Class
# 51287   40470   US-2013-155768   12/2/2013   2/12/2013        Same Day
# 51288    9596   MX-2012-140767  18-02-2012  18-02-2012  Standard Class
# 51289    6147   MX-2012-134460  22-05-2012  22-05-2012    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %%
df = data.copy()
print(df)
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891  31-07-2012  31-07-2012        Same Day
# 1       26341    IN-2013-77878    2/5/2013    5/2/2013    Second Class
# 2       25330    IN-2013-71249  17-10-2013  17-10-2013     First Class
# 3       13524  ES-2013-1579342  28-01-2013  28-01-2013     First Class
# 4       47221     SG-2013-4320   11/5/2013   5/11/2013        Same Day
# ...       ...              ...         ...         ...             ...
# 51285   29002    IN-2014-62366  19-06-2014  19-06-2014        Same Day
# 51286   35398   US-2014-102288  20-06-2014  20-06-2014  Standard Class
# 51287   40470   US-2013-155768   12/2/2013   2/12/2013        Same Day
# 51288    9596   MX-2012-140767  18-02-2012  18-02-2012  Standard Class
# 51289    6147   MX-2012-134460  22-05-2012  22-05-2012    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %%
df.head(5)
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1   26341    IN-2013-77878    2/5/2013    5/2/2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  17-10-2013  17-10-2013   First Class    CR-12730
# 3   13524  ES-2013-1579342  28-01-2013  28-01-2013   First Class    KM-16375
# 4   47221     SG-2013-4320   11/5/2013   5/11/2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
df.tail(10)
# Out:
#        Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 51280   46582    TU-2014-6730  29-11-2014  29-11-2014     First Class
# 51281    6039  MX-2014-169530    6/9/2014    9/6/2014     First Class
# 51282    9922  MX-2012-100258  28-12-2012  28-12-2012     First Class
# 51283   24105   IN-2014-72327  30-05-2014  30-05-2014        Same Day
# 51284   24175   IN-2014-57662    8/5/2014    5/8/2014  Standard Class
# 51285   29002   IN-2014-62366  19-06-2014  19-06-2014        Same Day
# 51286   35398  US-2014-102288  20-06-2014  20-06-2014  Standard Class
# 51287   40470  US-2013-155768   12/2/2013   2/12/2013        Same Day
# 51288    9596  MX-2012-140767  18-02-2012  18-02-2012  Standard Class
# 51289    6147  MX-2012-134460  22-05-2012  22-05-2012    Second Class
#
#       Customer ID      Customer Name      Segment               City  \
# 51280     KF-6285     Karen Ferguson  Home Office             Midyat
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %%
df.shape
# Out:
# (51290, 24)

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales      Quantity      Discount  \
# count  51290.00000   9994.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000  55190.379428    246.490581      3.476545      0.142908
# std    14806.29199  32063.693350    487.565361      2.278766      0.212280
# min        1.00000   1040.000000      0.444000      1.000000      0.000000
# 25%    12823.25000  23223.000000     30.758625      2.000000      0.000000
# 50%    25645.50000  56430.500000     85.053000      3.000000      0.000000
# 75%    38467.75000  90008.000000    251.053200      5.000000      0.200000
# max    51290.00000  99301.000000  22638.480000     14.000000      0.850000
#
#              Profit  Shipping Cost
# count  51290.000000   51290.000000
# mean      28.610982      26.375915
# std      174.340972      57.296804
# min    -6599.978000       0.000000
# 25%        0.000000       2.610000
# 50%        9.240000       7.790000
# 75%       36.810000      24.450000
# ...

# %%
df.describe(include='all')
# Out:
#              Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# count   51290.00000           51290       51290       51290           51290
# unique          NaN           25035        1430        1430               4
# top             NaN  CA-2014-100111  18-06-2014  18-06-2014  Standard Class
# freq            NaN              14         135         135           30775
# mean    25645.50000             NaN         NaN         NaN             NaN
# std     14806.29199             NaN         NaN         NaN             NaN
# min         1.00000             NaN         NaN         NaN             NaN
# 25%     12823.25000             NaN         NaN         NaN             NaN
# 50%     25645.50000             NaN         NaN         NaN             NaN
# 75%     38467.75000             NaN         NaN         NaN             NaN
# max     51290.00000             NaN         NaN         NaN             NaN
#
# ...

# %%
df.dtypes
# Out:
# Row ID              int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# City               object
# State              object
# Country            object
# Postal Code       float64
# Market             object
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# Shipping Cost     float64
# Order Priority     object
# dtype: object

# %%
#columns that contain float values
float_type = df[['Postal Code', 'Sales', 'Discount', 'Profit', 'Shipping Cost']]
float_type.head()
# Out:
#    Postal Code     Sales  Discount    Profit  Shipping Cost
# 0      10024.0  2309.650       0.0  762.1845         933.57
# 1          NaN  3709.395       0.1 -288.7650         923.63
# 2          NaN  5175.171       0.1  919.9710         915.49
# 3          NaN  2892.510       0.1  -96.5400         910.16
# 4          NaN  2832.960       0.0  311.5200         903.04

# %%
else_type = df[['Row ID', 'Order ID', 'Ship Mode', 'Customer ID', 'Customer Name',
                'Segment', 'City', 'State', 'Country']]
else_type.head()
# Out:
#    Row ID         Order ID     Ship Mode Customer ID     Customer Name  \
# 0   32298   CA-2012-124891      Same Day    RH-19495       Rick Hansen
# 1   26341    IN-2013-77878  Second Class    JR-16210     Justin Ritter
# 2   25330    IN-2013-71249   First Class    CR-12730      Craig Reiter
# 3   13524  ES-2013-1579342   First Class    KM-16375  Katherine Murray
# 4   47221     SG-2013-4320      Same Day     RH-9495       Rick Hansen
#
#        Segment           City            State        Country
# 0     Consumer  New York City         New York  United States
# 1    Corporate     Wollongong  New South Wales      Australia
# 2     Consumer       Brisbane       Queensland      Australia
# 3  Home Office         Berlin           Berlin        Germany
# 4     Consumer          Dakar            Dakar        Senegal

# %%
date_type = df [['Order Date', 'Ship Date']]
date_type.head()
# Out:
#    Order Date   Ship Date
# 0  31-07-2012  31-07-2012
# 1    2/5/2013    5/2/2013
# 2  17-10-2013  17-10-2013
# 3  28-01-2013  28-01-2013
# 4   11/5/2013   5/11/2013

# %%
df ['Order Date'] = pd.to_datetime(df['Order Date'], format = 'mixed', errors = 'coerce')

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format = 'mixed')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format = 'mixed')
print(df[['Order Date', 'Ship Date']].dtypes)
# Out:
# Order Date    datetime64[ns]
# Ship Date     datetime64[ns]
# dtype: object

# %%
df.nunique()
# Out:
# Row ID            51290
# Order ID          25035
# Order Date         1430
# Ship Date          1430
# Ship Mode             4
# Customer ID        1590
# Customer Name       795
# Segment               3
# City               3636
# State              1094
# Country             147
# Postal Code         631
# Market                7
# Region               13
# Product ID        10292
# Category              3
# Sub-Category         17
# Product Name       3788
# Sales             22995
# Quantity             14
# Discount             27
# Profit            24575
# Shipping Cost     10037
# Order Priority        4
# dtype: int64

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# City                      object
# State                     object
# Country                   object
# Postal Code              float64
# Market                    object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df['Ship Mode'] = df['Ship Mode'].astype('category')
df['Segment'] = df['Segment'].astype('category')
df['Country'] = df['Country'].astype('category')
df['Market'] = df['Market'].astype('category')
df['Region'] = df['Region'].astype('category')
df['Category'] = df['Category'].astype('category')
df['Sub-Category'] = df['Sub-Category'].astype('category')
df['Order Priority'] = df['Order Priority'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  category
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  category
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  category
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  category
#  13  Region          51290 non-null  category
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  category
# ...

# %% [markdown]
# **DATA CLEANING**

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
df.shape
# Out:
# (51290, 24)

# %%
df.nunique()
# Out:
# Row ID            51290
# Order ID          25035
# Order Date         1430
# Ship Date          1430
# Ship Mode             4
# Customer ID        1590
# Customer Name       795
# Segment               3
# City               3636
# State              1094
# Country             147
# Postal Code         631
# Market                7
# Region               13
# Product ID        10292
# Category              3
# Sub-Category         17
# Product Name       3788
# Sales             22995
# Quantity             14
# Discount             27
# Profit            24575
# Shipping Cost     10037
# Order Priority        4
# dtype: int64

# %%
postal_code_mode = df['Postal Code']. mode()[0]
postal_code_mode
# Out:
# 10035.0

# %%
df['Postal Code'] = df['Postal Code'].fillna(postal_code_mode)
df['Postal Code'].head()
# Out:
# 0    10024.0
# 1    10035.0
# 2    10035.0
# 3    10035.0
# 4    10035.0
# Name: Postal Code, dtype: float64

# %%
df['Postal Code'].isnull().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
Sales_negative = df['Sales']>=0
Sales_negative
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 51285    True
# 51286    True
# 51287    True
# 51288    True
# 51289    True
# Name: Sales, Length: 51290, dtype: bool

# %%
negative_sales = df[df['Sales']<0]
if not negative_sales.empty:
  print(negative_sales)
  negative_sales

# %%
negative_profit = df[df["Profit"]<0]
if not negative_profit.empty:
  print("Negative vales in 'Profit':")
  display(negative_profit.head(45))
# Out:
# Negative vales in 'Profit':
#      Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 1     26341    IN-2013-77878 2013-02-05 2013-05-02    Second Class
# 3     13524  ES-2013-1579342 2013-01-28 2013-01-28     First Class
# 9     40936   CA-2012-116638 2012-01-28 2012-01-28    Second Class
# 30      220   US-2011-128776 2011-12-28 2011-12-28    Second Class
# 32    32735   CA-2012-139731 2012-10-15 2012-10-15        Same Day
# 37    31980   US-2014-168116 2014-11-05 2014-05-11        Same Day
# 40    21316    ID-2013-63976 2013-08-22 2013-08-22  Standard Class
# 73    21209    IN-2014-30110 2014-08-26 2014-08-26     First Class
# 83    38540   CA-2014-118892 2014-08-18 2014-08-18    Second Class
# 85    23013    ID-2012-78207 2012-09-18 2012-09-18    Second Class
# 98    15896  IT-2012-1779015 2012-09-29 2012-09-29        Same Day
# 109   11743  IT-2013-5208514 2013-03-13 2013-03-13        Same Day
# 111   17522  ES-2012-2314672 2012-04-05 2012-05-04        Same Day
# ...

# %%
mean_profit= df[df['Profit']>=0]['Profit'].mean()
data.loc[data['Profit']<0, 'Profit'] = mean_profit
mean_profit
# Out:
# 61.634838357507874

# %%
df['Profit'] = df['Profit'].apply(lambda x: mean_profit if x<0 else x)
print(df['Profit'].head(5))
# Out:
# 0    762.184500
# 1     61.634838
# 2    919.971000
# 3     61.634838
# 4    311.520000
# Name: Profit, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  category
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  category
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  category
#  11  Postal Code     51290 non-null  float64
#  12  Market          51290 non-null  category
#  13  Region          51290 non-null  category
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  category
# ...

# %% [markdown]
# **Segment the Data**

# %%
segment_data = df[['Customer ID', 'Customer Name', 'Category',
                   'Product Name', 'Sub-Category', 'Sales', 'Profit', 'Quantity',
                   'Discount', 'Order Date', 'City', 'State', 'Region', 'Market',
                   'Order Priority']]
segment_data.head()
# Out:
#   Customer ID     Customer Name    Category  \
# 0    RH-19495       Rick Hansen  Technology
# 1    JR-16210     Justin Ritter   Furniture
# 2    CR-12730      Craig Reiter  Technology
# 3    KM-16375  Katherine Murray  Technology
# 4     RH-9495       Rick Hansen  Technology
#
#                                         Product Name Sub-Category     Sales  \
# 0  Plantronics CS510 - Over-the-Head monaural Wir...  Accessories  2309.650
# 1          Novimex Executive Leather Armchair, Black       Chairs  3709.395
# 2                  Nokia Smart Phone, with Caller ID       Phones  5175.171
# 3                     Motorola Smart Phone, Cordless       Phones  2892.510
# 4                     Sharp Wireless Fax, High-Speed      Copiers  2832.960
#
#        Profit  Quantity  Discount Order Date           City            State  \
# 0  762.184500         7       0.0 2012-07-31  New York City         New York
# 1   61.634838         9       0.1 2013-02-05     Wollongong  New South Wales
# ...

# %% [markdown]
# # **Sales and Profit Analysis**
#
# 1. What is the trend sales and profit over time?
# 2. Which regions and markets contribute the most to sales and profit?
# 3. Which cities and states are the most profitable?
# 4. Which product are the most popular (highest quantity sold)?
# 5. What is the sales and profit distribution acress different markets?

# %% [markdown]
# # **What is the trend sales and provit over time?**

# %%
segment_data.loc[:, 'Order Date'] = pd.to_datetime(segment_data['Order Date'])
segment_data.loc[:, 'Year'] = segment_data['Order Date'].dt.year
sales_profit_trend = segment_data.groupby('Year')[['Sales', 'Profit']].sum()
print(sales_profit_trend)
# Out:
#              Sales        Profit
# Year
# 2011  2.259451e+06  5.552016e+05
# 2012  2.677439e+06  6.684937e+05
# 2013  3.405746e+06  8.575934e+05
# 2014  4.299866e+06  1.079962e+06
# <ipython-input-92-bd6e563967e4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   segment_data.loc[:, 'Year'] = segment_data['Order Date'].dt.year

# %%
plt.figure(figsize=(8, 6))
plt.plot(sales_profit_trend['Sales'], label='Sales', color='#1f77b4', linewidth=2.5, marker='o')
plt.plot(sales_profit_trend['Profit'], label='Profit', color='#2ca02c', linewidth=2.5, marker='o')

plt.title('Sales and Profit Trend Over Time', fontsize=16, fontweight='bold', color='darkblue')
plt.xlabel('Year', fontsize=12, fontweight='bold')
plt.ylabel('Amount($)', fontsize=12, fontweight='bold')
plt.grid(True, linestyle='--')
plt.legend(loc='upper left', fontsize=12)

plt.tight_layout()

plt.show()

# %% [markdown]
# **Sales and Profit Trend Report**
#
# Grafik menunjukkan tren naik yang konsisten (garis biru menunjukkan penjualan dan garis hijau menunjukkan keuntungan) selama bertahun-tahun setiap 6 bulannya. Pertumbuhan penjualan menunjukkan peningkatan pendapatan, sementara pertumbuhan keutungan menunjukkan peningkatan profitabilitas. Fluktuasi dari tahun ke tahun menunjukkan dampak pasar dan operasional, tetapi keseluruhan menunjukkan kinerja bisnis yang kuat.

# %% [markdown]
# # Which regions and markets contribute the most to sales and profit?

# %%
region_market_sales_profit = segment_data.groupby(['Region', 'Market'], observed=False)[['Sales', 'Profit']].sum()
top_region_sales= region_market_sales_profit.sort_values(by='Sales', ascending=False)
top_market_sales= region_market_sales_profit.sort_values(by='Profit', ascending=False)

# %%
print('Top Regions by Sales')
top_region_sales[['Sales']].head()
# Out:
# Top Regions by Sales
#                               Sales
# Region         Market
# Central        EU      1.720553e+06
# Oceania        APAC    1.100185e+06
# Southeast Asia APAC    8.844232e+05
# North Asia     APAC    8.483098e+05
# EMEA           EMEA    8.061613e+05

# %%
print("\nTop Markets by Profit:")
top_market_sales[['Profit']].head()
# Out:
# Top Markets by Profit:
#                               Profit
# Region         Market
# Central        EU      380670.456092
# EMEA           EMEA    265949.434402
# Oceania        APAC    241333.589821
# Africa         Africa  241230.547508
# Southeast Asia APAC    210130.967780

# %%
top_regions_sales = region_market_sales_profit.sort_values(by='Sales', ascending=False).head()
top_markets_profit= region_market_sales_profit.sort_values(by='Profit', ascending=False).head()

fig, ax = plt.subplots(2, 1, figsize=(8, 8))

top_regions_sales[['Sales', 'Profit']].plot(kind='bar', stacked=True, ax=ax[0], color=['#1f77b4', '#2ca02c'])
ax[0].set_title('Top Regions by Sales and Profit', fontsize=14, color='darkblue')
ax[0].set_ylabel('Amount($)', fontsize=12)
ax[0].set_xlabel('Region', fontsize=12)

top_markets_profit[['Sales', 'Profit']].plot(kind='bar', stacked=True, ax=ax[1], color=['#1f77b4', '#2ca02c'])
ax[1].set_title('Top Markets by Sales and Profit', fontsize=14, color='darkblue')
ax[1].set_ylabel('Amount($)', fontsize=12)
ax[1].set_xlabel('Market', fontsize=12)

plt.tight_layout()

plt.show()

# %% [markdown]
# **Most Profitable Regions dan Markets**
#
# Analisis ini menyoroti wilayah dan pasar yang memberikan kontribusi terbesar terhadap penjualan dan keuntungan. Diagram batang bertumpuk digunakan untuk membandingkan data penjualan dan keuntungan di berbagai wilayah serta pasar. Batang berwarna biru menunjukkan penjualan, sedangkan batang hijau menunjukkan keuntungan, sehingga memudahkan visualisasi wilayah dan pasar yang paling menguntungkan. Diagram ini dengan jelas mengidentifikasi wilayah dan pasar berkinerja tinggi, memberikan wawasan tentang faktor utama yang mendorong pertumbuhan penjualan dan keuntungan.

# %% [markdown]
# #Which cities and states are the most profitable?

# %%
city_states_profit = segment_data.groupby(['City', 'State'])['Profit'].sum().reset_index()

top_city_states_profit = city_states_profit.sort_values(by='Profit', ascending=False).head()
top_city_states_profit
# Out:
#                City             State        Profit
# 2402  New York City          New York  68468.399834
# 2006    Los Angeles        California  33891.576919
# 3085        Seattle        Washington  30527.425014
# 2096         Manila  National Capital  26143.423492
# 1580        Jakarta           Jakarta  25412.669240

# %%
top_city_states_profit = city_states_profit.sort_values(by='Profit', ascending=False).head()

fig, ax=plt.subplots(figsize=(10,6))

top_city_states_profit.plot(kind='bar', x='City', y='Profit', ax=ax, color='#2ca02c')

ax.set_title('Top Cities by Profit', fontsize=14, color='darkblue')
ax.set_ylabel('Profit ($)', fontsize=12)
ax.set_xlabel('City', fontsize=12)

plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Most Profitable Cities and States**
#
# Analisis ini mengidentifikasi kota dan negara bagian dengan kontribusi keuntungan terbesar. Diagram batang horizontal menampilkan pasangan kota dan negara bagian yang paling menguntungkan, dengan nilai keuntungan yang lebih tinggi terlihat dengan jelas. Kota-kota dengan keuntungan tertinggi menonjol, memungkinkan perbandingan profitabilitas secara cepat. Batang berwarna hijau menunjukkan total keuntungan, memberikan wawasan tentang area utama dalam kinerja bisnis.

# %% [markdown]
# #Which product are the most popular (highest quantity sold)?

# %%
product_quantity = segment_data.groupby('Product Name')['Quantity'].sum().reset_index()

top_products = product_quantity.sort_values(by='Quantity', ascending=False).head()
top_products
# Out:
#                                Product Name  Quantity
# 3275                                Staples       876
# 894               Cardinal Index Tab, Clear       337
# 1210          Eldon File Cart, Single Width       321
# 2840         Rogers File Cart, Single Width       262
# 3070  Sanford Pencil Sharpener, Water Color       259

# %%
top_products = product_quantity.sort_values(by='Quantity', ascending=False).head()

fig, ax = plt. subplots(figsize=(10,6))

ax.pie(top_products['Quantity'], labels=top_products['Product Name'], autopct='%1.1f%%', colors=['#1f77b4', '#2ca02c', '#ff7f0e', '#d62728', '#9467bd'])

ax.set_title('Top Products by Quantity Sold', fontsize=14, color='darkblue')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Report: Most Popular Products by Quantity Sold**
#
# Analisis ini menyoroti produk terlaris berdasarkan jumlah yang terjual. Diagram lingkaran digunakan untuk menampilkan proporsi penjualan setiap produk, di mana setiap produk direpresentasikan dengan warna yang berbeda. Segmen berwarna biru menunjukkan produk paling populer, sedangkan segmen berwarna hijau dan warna lainnya mewakili produk teratas berikutnya.
#
# Diagram ini secara efektif menggambarkan pangsa setiap produk dalam total jumlah penjualan, memberikan gambaran yang jelas tentang produk paling populer dalam dataset. Representasi visual ini memungkinkan perbandingan popularitas produk berdasarkan volume penjualan dengan mudah.

# %% [markdown]
# # What is the sales and profit distribution acress different markets?

# %%
market_sales_profit = segment_data.groupby('Market', observed=False)[['Sales', 'Profit']].sum().reset_index()
market_sales_profit
# Out:
#    Market         Sales         Profit
# 0    APAC  3.585744e+06  835093.627750
# 1  Africa  7.837732e+05  241230.547508
# 2  Canada  6.692817e+04   17817.390000
# 3    EMEA  8.061613e+05  265949.434402
# 4      EU  2.938089e+06  689561.324641
# 5   LATAM  2.164605e+06  553751.445089
# 6      US  2.297201e+06  557847.089967

# %%
fig, ax = plt.subplots(figsize=(10,6))

market_sales_profit.set_index('Market')[['Sales', 'Profit']].plot(kind='bar', stacked=True, ax=ax, color=['#1f77b4', '#2ca02c'])

ax.set_title('Sales and Profit Distribution Across Different Markets', fontsize=14, color='darkblue')
ax.set_ylabel('Amount ($)', fontsize=12)
ax.set_xlabel('Market', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Report: Sales and Profit Distribution Across Different Markets**
#
# Analisis distribusi penjualan dan keuntungan di berbagai pasar divisualisasikan menggunakan diagram batang bertumpuk. Diagram ini menampilkan penjualan dalam warna biru dan keuntungan dalam warna hijau untuk setiap pasar. Dengan menumpuk nilai-nilai ini, perbandingan kontribusi total penjualan dan keuntungan di setiap pasar menjadi lebih mudah.
#
# Diagram ini menyoroti pasar yang paling menguntungkan dan menghasilkan penjualan tertinggi. Pasar dengan batang yang lebih besar menunjukkan tingkat penjualan dan keuntungan yang lebih tinggi secara keseluruhan, sementara batang yang lebih kecil menunjukkan kontribusi yang lebih rendah. Visualisasi ini memberikan pemahaman yang jelas dan komparatif tentang kinerja pasar dalam hal penjualan dan profitabilitas.
